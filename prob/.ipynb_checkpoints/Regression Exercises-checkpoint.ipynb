# %%
import numpy as np
import random

# %%
# Generate a linear model with homoscedastic noise
n_samples = 100

xs = np.random.rand(3,n_samples)
A = np.random.rand(1,3)

ys = np.transpose(A.dot(xs)) + np.random.normal(n_samples, 1)

# %%
# OLS
# Out:
# array([[101.62920149],
#        [101.6429725 ],
#        [101.43925346],
#        [101.16662345],
#        [101.11971787],
#        [100.46059523],
#        [101.21004154],
#        [100.7931524 ],
#        [101.23753653],
#        [101.28529807],
#        [100.6185617 ],
#        [101.01277791],
#        [100.96318052],
#        [101.01717049],
#        [101.29888077],
#        [100.97998777],
#        [101.64780578],
#        [100.98257931],
#        [101.03296668],
#        [101.24595305],
#        [100.9032343 ],
#        [100.71095219],
#        [101.0281363 ],
#        [101.52249879],
#        [100.83832099],
#        [101.4756534 ],
#        [101.72054793],
#        [101.5252089 ],
#        [101.61818747],
#        [101.01693496],
#        [101.75254351],
#        [100.96487437],
#        [101.14857192],
#        [100.46093512],
#        [100.9225931 ],
#        [100.94500952],
#        [101.6690985 ],
#        [101.65800575],
#        [100.9625619 ],
#        [101.20053782],
# ...

# %%
# Bayesian Regression
